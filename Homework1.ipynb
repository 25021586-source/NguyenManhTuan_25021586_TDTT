# %% [markdown]
# <a href="https://colab.research.google.com/github/25021586-source/NguyenManhTuan_25021586_TDTT/blob/main/Homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bai1
n=int(input())
print(2*n)
# Out:
# 3
# 6

# %%
#bai2
a=int(input("chiều rộng "))
b=int(input("chiều dài "))
dien_tich=a*b-(a/2)**2*3.14
print("diện tích ",round(dien_tich,2))
# Out:
# chiều rộng 3
# chiều dài 4
# diện tích  4.93

# %%
#bai3
c=input("nhập 1 kí tự: ")
if len(c) !=1:
    print("nhập 1 kí tự")
elif 'A'<=c<='Z':
    print("chữ thường:",c.lower())
elif 'a'<=c<='z':
    print("chữ hoa:",c.upper())
else:
    print("nhập chữ")
# Out:
# nhập 1 kí tự: s
# chữ hoa: S

# %%
#bai4
c=input("nhập 1 kí tự:")
if c.isalpha():
  print(f"'{c}' là kí tự alphabet")
else:
  print(f"'{c}' không là kí tự alphabet")
# Out:
# nhập 1 kí tự:a
# 'a' là kí tự alphabet

# %%
#bai5
c=input("nhập 1 chữ cái in hoa:")
if len(c)!=1:
  print("nhập 1 kí tự")
elif c == 'A':
  print("trường hợp đặc biệt")
elif 'B'<=c<='Z':
  chu_truoc=chr(ord(c.lower())-1)
  print(f"chữ cái in thường liền trước '{c.lower()}' là:",chu_truoc)
else:
  print("nhập 1 chữ cái in hoa")
# Out:
# nhập 1 chữ cái in hoa:J
# chữ cái in thường liền trước 'j' là: i

# %%
#bai6
a,b,c=map(float,input("nhập 3 cạnh của 1 tam giác(cách nhau bởi dấu ','):").split(","))
if not a+b>c and b+c>a and c+a>b and a>0 and b>0 and c>0:
  print("khong phai 3 canh cua tam giac")
else:
  p=(a+b+c)/2
  s=(p*(p-a)*(p-b)*(p-c))**0.5
  print("diện tích tam giác:",round(s,1))
# Out:
# nhập 3 cạnh của 1 tam giác(cách nhau bởi dấu ','):4,5,2
# diện tích tam giác: 3.8

# %%
#bai7
a=input("nhập vào một chuỗi có độ dài >=20:")
print(a[4])
print(a[8])
# Out:
# nhập vào một chuỗi có độ dài >=20:hello nguyễn mạnh tuấn
# o
# u

# %%
#bai8
z=input("Ten chu ho:")
a=int(input("Chi so thang truoc:"))
b=int(input("Chi so thang nay:"))
c=b-a
if c>400:
  tien=(c-400)*3460+3350*100+2998*100+2380*100+2050*50+1984*50
  print(f"Ho va ten: {z} \nTien phai tra la:",int(tien*1.08))
elif c>300:
  tien=(c-300)*3350+2998*100+2380*100+2050*50+1984*50
  print(f"Ho va ten: {z} \nTien phai tra la:",int(tien*1.08))
elif c>200:
  tien=(c-200)*2998+2380*100+2050*50+1984*50
  print(f"Ho va ten: {z} \nTien phai tra la:",int(tien*1.08))
elif c>100:
  tien=(c-100)*2380+2050*50+1984*50
  print(f"Ho va ten: {z} \nTien phai tra la:",int(tien*1.08))
elif c>50:
  tien=(c-50)*2050+1984*50
  print(f"Ho va ten: {z} \nTien phai tra la:",int(tien*1.08))
else:
  tien=c*1984
  print(f"Ho va ten: {z} \nTien phai tra la:",int(tien*1.08))
# Out:
# Ten chu ho:Nguyen Xuan Long
# Chi so thang truoc:2097
# Chi so thang nay:2278
# Ho va ten: Nguyen Xuan Long
# Tien phai tra la: 426038
