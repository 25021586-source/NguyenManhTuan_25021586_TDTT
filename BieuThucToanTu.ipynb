# %% [markdown]
# <a href="https://colab.research.google.com/github/25021586-source/NguyenManhTuan_25021586_TDTT/blob/main/BieuThucToanTu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#W2A1
print("Hello World!")
# Out:
# Hello World!

# %%
#W2A2
x = input("tên :")
print("xin chào", x)
# Out:
# tên :tuấn
# xin chào tuấn

# %%
#W2A3
a = int(input("số a :"))
b = int(input("số b :"))
print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", round(a / b, 2))
print("a // b =", a // b)
print("a % b =", a % b)
# Out:
# số a :5
# số b :3
# a + b = 8
# a - b = 2
# a * b = 15
# a / b = 1.67
# a // b = 1
# a % b = 2

# %%
#W2A4
a1,a2,a3,b1,b2,c1 = map(float,input().split())
DiemTrungBinh=(a1+b1+c1+(a2+b2)*2+(a3)*3)/10
print(round(DiemTrungBinh,1))
# Out:
# 8 9 8 8 7 9
# 8.1

# %%
#W2A5
a,b=map(int,input().split())
print(f"{a}^{b} =", a**b)
# Out:
# 3 4
# 3^4 = 81

# %%
#W2A6
chu=str(input())
print("mã Unicode:",ord(chu))
print(f"in hoa của {chu} là ",chu.upper())
# Out:
# d
# mã Unicode: 100
# in hoa của d là  D

# %%
#W2A7
print(((13**2)*3)+5)
print(13**2*3+5)#bỏ các dấu ngoặc không làm thay đổi thứ tự thực hiện các phép toán
# Out:
# 512
# 512

# %%
#W2A8
a=float(input("nhiệt độ(*C):",))
b=(9/5)*a+32
print(f"nhiệt độ(*F): {b:.2f}")
# Out:
# nhiệt độ(*C):35
# nhiệt độ(*F): 95.00

# %%
#W2A9
a=float(input("giá đồng hồ Movado(USD):",))
b=a*0.4-10
print(f"tổng tiền phải trả(USD): {b:.2f}")
# Out:
# giá đồng hồ Movado(USD):100
# tổng tiền phải trả(USD): 30.00

# %%
#W2A10
a,b,c=map(str,input("tên:").split())
print(f"Hi {c}, {b} and {a}.")
# Out:
# tên:Tuấn Huy Thiện
# Hi Thiện, Huy and Tuấn.

# %%
#W2A11
a,b=map(float,input("số giờ, số phút: ").split(","))
print("số giây: ",3600*a+60*b)
# Out:
# số giờ, số phút: 4,6
# số giây:  14760.0

# %%
#W2A12
a=int(input("độ dài 1 cạnh của rubik: "))
print("số miếng dán:",a**2*6)
# Out:
# độ dài 1 cạnh của rubik: 3
# số miếng dán: 54

# %%
#W2A13
a=int(input("số a:"))
b=int(input("số b:"))
print("a*b =",a*b)
# Out:
# số a:4
# số b:6
# a*b = 24

# %%
#W2A14
a=int(input("số a:"))
b=int(input("số b:"))
a,b=b,a
print("a =",a)
print("b =",b)
# Out:
# số a:5
# số b:10
# a = 10
# b = 5

# %%
#W2A15
n=int(input("nhập số n:"))
print("số sao thứ n:",6*n*(n-1)+1)
# Out:
# nhập số n:4
# số sao thứ n: 73

# %%
#W2A16
print("spring","summer","autumn","winter",sep="\n")
# Out:
# spring
# summer
# autumn
# winter

# %%
#W2A17
print("*")
print("***")
print("*****")
# Out:
# *
# ***
# *****

# %%
#W2A18
print(" ### ##   ### ### ","  #  # #   #   #","  #  # #   #   #","  #  # #   #   #","  #  ##    #   #", sep="\n")
# Out:
#  ### ##   ### ###
#   #  # #   #   #
#   #  # #   #   #
#   #  # #   #   #
#   #  ##    #   #

# %%
#W2A19
print("Monday","Tuesday","Wednesday","Friday","Thusday","Saturday","Sunday",sep="\n")
# Out:
# Monday
# Tuesday
# Wednesday
# Friday
# Thusday
# Saturday
# Sunday

# %%
#W2A20
print("January","February","March","April","May","June","July","August","September","October","November","December",sep="\n")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for x in range(10):
  print("Hello World!")
# Out:
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
